# %%
# Install library EasyOCR
# !pip install easyocr

# Import library
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Membaca dan menampilkan gambar
Image_Path = '/content/image2.png'

img = cv2.imread(Image_Path)
plt.imshow(img)
plt.show()

# %%
# Membaca teks pada gambar
reader = easyocr.Reader(['id', 'en'])
result = reader.readtext(Image_Path)

img = cv2.imread(Image_Path)

# Menandai lokasi teks pada gambar
for i in range(len(result)-0):
  top_left = tuple(result[i][0][0])
  bottom_right = tuple(result[i][0][2])
  img = cv2.rectangle(img,top_left,bottom_right,(255,0,255),2)
# Out:
# WARNING:easyocr.easyocr:CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
# Menampilkan gambar
plt.imshow(img)
plt.show()

# Menampilkan hasil deteksi
print ('\n')
result
# Out:
# [([[127, 153], [658, 153], [658, 423], [127, 423]], 'TES', 0.9864456912500685),
#  ([[812, 139], [1734, 139], [1734, 446], [812, 446]],
#   'ANGKA',
#   0.9871253513294249),
#  ([[435, 582], [1462, 582], [1462, 890], [435, 890]],
#   '17452',
#   0.9495811519235342)]
